# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# $$
# y = a \cdot x^2 + b \cdot x + c
# $$

# %%
a = 2
b = 3
c = -5

# %%
x = np.arange(-10, 10, 0.5);
y = a*x**2 + b*x + c;

# %%
plt.plot(x, y)
plt.grid();
plt.xlabel("x")
plt.ylabel("y");
